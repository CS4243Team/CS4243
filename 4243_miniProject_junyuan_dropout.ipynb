# %%
#auto-complete
# %config Completer.use_jedi = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Colab Notebooks
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks
# '01 » ML Pipeline » CS3244 Machine Learning'
# '02 » Intro to Python Notebook and Math Review » CS3244 Machine Learning'
# 'Assignment 1 » CS3244 Machine Learning'
# '“Assignment 1 » CS3244 Machine Learning”的副本'
#  baseline_trained_dropout
#  baseline_trained_regularization
#  baseline_trained_regularization_100
# 'Copy of 04 » Curse of Dimensionality » CS3244 Machine Learning'
# 'Copy of lenet.ipynb'
# 'Copy of [Participants Copy] NUS Hackers X SDS: Numpy + Pandas Workshop.ipynb'
# 'Copy of Tutorial 03 » Linear Classifiers and Logistic Regression » CS3244 Machine Learning'
#  cs4243_CW1_progs_A0194484R.ipynb
#  cs4243NEWdata
#  cs4243_smallest
#  model.png
# '“Tutorial 03 » Linear Classifiers and Logistic Regression » CS3244 Machine Learning”的副本'
#  Untitled

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

img_height = 256
img_width = 256
image_size = (img_height, img_width)
batch_size = 8
epochs= 100

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/cs4243NEWdata/",
    labels='inferred',
    validation_split=0.2,
    subset="training",
    seed=110,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/cs4243NEWdata/",
    labels='inferred',
    validation_split=0.2,
    subset="validation",
    seed=110,
    image_size=image_size,
    batch_size=batch_size,
)

whole_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "/content/drive/My Drive/Colab Notebooks/cs4243NEWdata/",
    labels='inferred',
    seed=110,
    image_size=image_size,
    batch_size=batch_size,
)
print(type(val_ds))
class_names = train_ds.class_names
print(class_names)
# Out:
# Found 1516 files belonging to 3 classes.
# Using 1213 files for training.
# Found 1516 files belonging to 3 classes.
# Using 303 files for validation.
# Found 1516 files belonging to 3 classes.
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>
# ['carrying', 'normal', 'threat']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    print(images.shape)
    print(labels.shape)
    for i in range(8):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")
# Out:
# (8, 256, 256, 3)
# (8,)

# %%
import numpy as np
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.experimental.preprocessing.Normalization(mean=[0.485, 0.456, 0.406], variance=[np.square(0.299), 
                                np.square(0.224), 
                                np.square(0.225)])
  ]
)

# %%
# showing the rotated and flipped images that were added to the 
# original dataset
#
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
#Configure the dataset for performance
augmented_train_ds = train_ds.map( lambda x, y: (data_augmentation(x, training=True), y))
#augmented_val_ds = val_ds.map( lambda x, y: (data_augmentation(x, training=True), y))

augmented_train_ds = augmented_train_ds.prefetch(buffer_size=32)
#augmented_val_ds = augmented_val_ds.prefetch(buffer_size=32)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)

# %%
if tf.test.gpu_device_name(): 
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
   print("Please install GPU version of TF")
# Out:
# Default GPU Device: /device:GPU:0

# %%
#standardization

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

num_classes = len(class_names)

# model = Sequential([
#   layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
#   layers.Conv2D(16, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(32, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Conv2D(64, 3, padding='same', activation='relu'),
#   layers.MaxPooling2D(),
#   layers.Flatten(),
#   layers.Dense(128, activation='relu'),
#   layers.Dense(num_classes)
# ])

model = Sequential([
    # layer 0
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    # layer 1
    layers.Conv2D(16, (3,3), padding='same', activation='relu', use_bias=True),
    layers.MaxPooling2D(2,2),
    # layer 2
    layers.Conv2D(32, (3,3), padding='same', activation = 'relu', use_bias=True),
    layers.MaxPooling2D(2,2),
    # layer 3
    layers.Conv2D(64, (3,3), padding='same', activation = 'relu', use_bias=True),
    layers.MaxPooling2D(2,2),
    # layer 4
    layers.Conv2D(128, (3,3), padding='same', activation = 'relu', use_bias=True),
    layers.MaxPooling2D(2,2),
    # layer 5
    layers.Conv2D(256, (3,3), padding='same', activation = 'relu', use_bias=True),
    layers.MaxPooling2D(2,2),
    layers.Flatten(),
    # layer 6
    layers.Dense(512, activation = 'relu', use_bias=True),
    layers.Dropout( 0.2),
    # layer 7
    layers.Dense(num_classes, activation='softmax', use_bias=True)
    
])

# %%
#opimizer
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        18496
#
#  dropout (Dropout)           (None, 64, 64, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       73856
#
#  dropout_1 (Dropout)         (None, 32, 32, 128)       0
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 256)       295168
#
#  dropout_2 (Dropout)         (None, 16, 16, 256)       0
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 512)               8389120
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 3)                 1539
#
# =================================================================
# Total params: 8,783,267
# Trainable params: 8,783,267
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
history = model.fit(
  augmented_train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 152/152 [==============================] - 372s 2s/step - loss: 1.2059 - accuracy: 0.3281 - val_loss: 1.1550 - val_accuracy: 0.3993
# Epoch 2/100
# 152/152 [==============================] - 58s 370ms/step - loss: 1.0999 - accuracy: 0.3578 - val_loss: 1.1023 - val_accuracy: 0.3300
# Epoch 3/100
# 152/152 [==============================] - 57s 359ms/step - loss: 1.0973 - accuracy: 0.3545 - val_loss: 1.1674 - val_accuracy: 0.3333
# Epoch 4/100
# 152/152 [==============================] - 59s 376ms/step - loss: 1.0897 - accuracy: 0.3825 - val_loss: 1.0924 - val_accuracy: 0.3399
# Epoch 5/100
# 152/152 [==============================] - 59s 371ms/step - loss: 1.0963 - accuracy: 0.3561 - val_loss: 1.2020 - val_accuracy: 0.3300
# Epoch 6/100
# 152/152 [==============================] - 56s 356ms/step - loss: 1.0978 - accuracy: 0.3768 - val_loss: 1.1503 - val_accuracy: 0.3696
# Epoch 7/100
# 152/152 [==============================] - 57s 360ms/step - loss: 1.0782 - accuracy: 0.3842 - val_loss: 1.0862 - val_accuracy: 0.3795
# Epoch 8/100
# 152/152 [==============================] - 56s 355ms/step - loss: 1.0722 - accuracy: 0.3916 - val_loss: 1.2232 - val_accuracy: 0.3333
# Epoch 9/100
# 152/152 [==============================] - 57s 358ms/step - loss: 1.0594 - accuracy: 0.4130 - val_loss: 1.2980 - val_accuracy: 0.3333
# Epoch 10/100
# 152/152 [==============================] - 59s 373ms/step - loss: 1.0522 - accuracy: 0.4270 - val_loss: 1.2470 - val_accuracy: 0.3333
# Epoch 11/100
# 152/152 [==============================] - 57s 364ms/step - loss: 1.0446 - accuracy: 0.4534 - val_loss: 1.1577 - val_accuracy: 0.3333
# Epoch 12/100
# 152/152 [==============================] - 58s 366ms/step - loss: 1.0260 - accuracy: 0.4641 - val_loss: 1.3249 - val_accuracy: 0.3333
# Epoch 13/100
# 152/152 [==============================] - 57s 360ms/step - loss: 1.0189 - accuracy: 0.4691 - val_loss: 1.1397 - val_accuracy: 0.3498
# Epoch 14/100
# 152/152 [==============================] - 59s 372ms/step - loss: 1.0012 - accuracy: 0.4839 - val_loss: 1.1819 - val_accuracy: 0.3333
# Epoch 15/100
# 152/152 [==============================] - 57s 362ms/step - loss: 0.9877 - accuracy: 0.4930 - val_loss: 1.2208 - val_accuracy: 0.3333
# Epoch 16/100
# 152/152 [==============================] - 57s 358ms/step - loss: 0.9907 - accuracy: 0.5054 - val_loss: 1.2916 - val_accuracy: 0.3333
# Epoch 17/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.9554 - accuracy: 0.5293 - val_loss: 1.3118 - val_accuracy: 0.3333
# Epoch 18/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.9623 - accuracy: 0.5342 - val_loss: 1.2691 - val_accuracy: 0.3333
# Epoch 19/100
# 152/152 [==============================] - 58s 368ms/step - loss: 0.9176 - accuracy: 0.5787 - val_loss: 1.3017 - val_accuracy: 0.3333
# Epoch 20/100
# 152/152 [==============================] - 56s 352ms/step - loss: 0.9128 - accuracy: 0.5647 - val_loss: 1.4295 - val_accuracy: 0.3366
# Epoch 21/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.8809 - accuracy: 0.5754 - val_loss: 1.2549 - val_accuracy: 0.3333
# Epoch 22/100
# 152/152 [==============================] - 57s 359ms/step - loss: 0.8817 - accuracy: 0.5919 - val_loss: 1.3758 - val_accuracy: 0.3432
# Epoch 23/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.8600 - accuracy: 0.6142 - val_loss: 1.6840 - val_accuracy: 0.3333
# Epoch 24/100
# 152/152 [==============================] - 57s 363ms/step - loss: 0.8429 - accuracy: 0.6043 - val_loss: 1.5715 - val_accuracy: 0.3498
# Epoch 25/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.8141 - accuracy: 0.6290 - val_loss: 2.0604 - val_accuracy: 0.3333
# Epoch 26/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.7991 - accuracy: 0.6455 - val_loss: 2.0281 - val_accuracy: 0.3399
# Epoch 27/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.7927 - accuracy: 0.6356 - val_loss: 1.5407 - val_accuracy: 0.3432
# Epoch 28/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.7839 - accuracy: 0.6472 - val_loss: 1.4556 - val_accuracy: 0.3333
# Epoch 29/100
# 152/152 [==============================] - 58s 366ms/step - loss: 0.7450 - accuracy: 0.6727 - val_loss: 1.8790 - val_accuracy: 0.3333
# Epoch 30/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.7532 - accuracy: 0.6801 - val_loss: 1.5775 - val_accuracy: 0.3366
# Epoch 31/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.7044 - accuracy: 0.6900 - val_loss: 1.7343 - val_accuracy: 0.3432
# Epoch 32/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.6729 - accuracy: 0.7172 - val_loss: 1.9554 - val_accuracy: 0.3366
# Epoch 33/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.6827 - accuracy: 0.7082 - val_loss: 1.6854 - val_accuracy: 0.3366
# Epoch 34/100
# 152/152 [==============================] - 58s 368ms/step - loss: 0.6670 - accuracy: 0.7222 - val_loss: 2.3992 - val_accuracy: 0.3333
# Epoch 35/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.6385 - accuracy: 0.7230 - val_loss: 2.1268 - val_accuracy: 0.3267
# Epoch 36/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.6299 - accuracy: 0.7370 - val_loss: 2.3740 - val_accuracy: 0.3333
# Epoch 37/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.6207 - accuracy: 0.7321 - val_loss: 2.2836 - val_accuracy: 0.3333
# Epoch 38/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.5881 - accuracy: 0.7560 - val_loss: 3.0549 - val_accuracy: 0.3399
# Epoch 39/100
# 152/152 [==============================] - 57s 364ms/step - loss: 0.5795 - accuracy: 0.7700 - val_loss: 2.4098 - val_accuracy: 0.3168
# Epoch 40/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.5511 - accuracy: 0.7708 - val_loss: 2.2514 - val_accuracy: 0.3333
# Epoch 41/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.5467 - accuracy: 0.7716 - val_loss: 2.0456 - val_accuracy: 0.3366
# Epoch 42/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.5490 - accuracy: 0.7815 - val_loss: 2.8458 - val_accuracy: 0.3366
# Epoch 43/100
# 152/152 [==============================] - 56s 352ms/step - loss: 0.5392 - accuracy: 0.7782 - val_loss: 4.4240 - val_accuracy: 0.3333
# Epoch 44/100
# 152/152 [==============================] - 57s 363ms/step - loss: 0.5686 - accuracy: 0.7683 - val_loss: 2.7793 - val_accuracy: 0.3333
# Epoch 45/100
# 152/152 [==============================] - 55s 351ms/step - loss: 0.5213 - accuracy: 0.7890 - val_loss: 2.5440 - val_accuracy: 0.3465
# Epoch 46/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.4570 - accuracy: 0.8170 - val_loss: 5.6630 - val_accuracy: 0.3333
# Epoch 47/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.4906 - accuracy: 0.8005 - val_loss: 4.3680 - val_accuracy: 0.3300
# Epoch 48/100
# 152/152 [==============================] - 56s 352ms/step - loss: 0.4454 - accuracy: 0.8359 - val_loss: 3.5369 - val_accuracy: 0.3333
# Epoch 49/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.4289 - accuracy: 0.8376 - val_loss: 4.1202 - val_accuracy: 0.3300
# Epoch 50/100
# 152/152 [==============================] - 57s 358ms/step - loss: 0.4368 - accuracy: 0.8343 - val_loss: 4.5037 - val_accuracy: 0.3399
# Epoch 51/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.4255 - accuracy: 0.8277 - val_loss: 5.3620 - val_accuracy: 0.3333
# Epoch 52/100
# 152/152 [==============================] - 55s 351ms/step - loss: 0.4031 - accuracy: 0.8483 - val_loss: 4.4383 - val_accuracy: 0.3531
# Epoch 53/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.4091 - accuracy: 0.8442 - val_loss: 3.6246 - val_accuracy: 0.3300
# Epoch 54/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.3769 - accuracy: 0.8640 - val_loss: 4.7892 - val_accuracy: 0.3333
# Epoch 55/100
# 152/152 [==============================] - 57s 364ms/step - loss: 0.4094 - accuracy: 0.8434 - val_loss: 2.8647 - val_accuracy: 0.3333
# Epoch 56/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.4019 - accuracy: 0.8384 - val_loss: 4.3488 - val_accuracy: 0.3366
# Epoch 57/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.3695 - accuracy: 0.8483 - val_loss: 7.0213 - val_accuracy: 0.3333
# Epoch 58/100
# 152/152 [==============================] - 57s 359ms/step - loss: 0.3358 - accuracy: 0.8673 - val_loss: 4.0428 - val_accuracy: 0.3465
# Epoch 59/100
# 152/152 [==============================] - 56s 358ms/step - loss: 0.3447 - accuracy: 0.8607 - val_loss: 3.6409 - val_accuracy: 0.3300
# Epoch 60/100
# 152/152 [==============================] - 58s 366ms/step - loss: 0.3337 - accuracy: 0.8574 - val_loss: 4.5557 - val_accuracy: 0.3300
# Epoch 61/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.3493 - accuracy: 0.8714 - val_loss: 3.5081 - val_accuracy: 0.3333
# Epoch 62/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.3258 - accuracy: 0.8648 - val_loss: 5.4171 - val_accuracy: 0.3333
# Epoch 63/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.3177 - accuracy: 0.8912 - val_loss: 3.7696 - val_accuracy: 0.3366
# Epoch 64/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.3203 - accuracy: 0.8730 - val_loss: 3.1575 - val_accuracy: 0.3432
# Epoch 65/100
# 152/152 [==============================] - 68s 433ms/step - loss: 0.3258 - accuracy: 0.8862 - val_loss: 4.7585 - val_accuracy: 0.3366
# Epoch 66/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.3003 - accuracy: 0.8895 - val_loss: 3.9132 - val_accuracy: 0.3300
# Epoch 67/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.2928 - accuracy: 0.8796 - val_loss: 2.7757 - val_accuracy: 0.3432
# Epoch 68/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.3189 - accuracy: 0.8879 - val_loss: 3.6073 - val_accuracy: 0.3366
# Epoch 69/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.3076 - accuracy: 0.8904 - val_loss: 3.2734 - val_accuracy: 0.3267
# Epoch 70/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.2708 - accuracy: 0.9044 - val_loss: 4.5106 - val_accuracy: 0.3234
# Epoch 71/100
# 152/152 [==============================] - 59s 373ms/step - loss: 0.2445 - accuracy: 0.9134 - val_loss: 2.6990 - val_accuracy: 0.3003
# Epoch 72/100
# 152/152 [==============================] - 58s 366ms/step - loss: 0.3130 - accuracy: 0.8871 - val_loss: 4.4896 - val_accuracy: 0.3333
# Epoch 73/100
# 152/152 [==============================] - 57s 363ms/step - loss: 0.2624 - accuracy: 0.8945 - val_loss: 4.4932 - val_accuracy: 0.3465
# Epoch 74/100
# 152/152 [==============================] - 57s 362ms/step - loss: 0.2826 - accuracy: 0.8978 - val_loss: 3.6681 - val_accuracy: 0.3300
# Epoch 75/100
# 152/152 [==============================] - 57s 361ms/step - loss: 0.2394 - accuracy: 0.9134 - val_loss: 3.8387 - val_accuracy: 0.3267
# Epoch 76/100
# 152/152 [==============================] - 58s 371ms/step - loss: 0.2655 - accuracy: 0.9151 - val_loss: 4.9715 - val_accuracy: 0.3399
# Epoch 77/100
# 152/152 [==============================] - 57s 358ms/step - loss: 0.2442 - accuracy: 0.9052 - val_loss: 4.6779 - val_accuracy: 0.3300
# Epoch 78/100
# 152/152 [==============================] - 57s 361ms/step - loss: 0.2303 - accuracy: 0.9225 - val_loss: 4.0971 - val_accuracy: 0.3201
# Epoch 79/100
# 152/152 [==============================] - 57s 360ms/step - loss: 0.1995 - accuracy: 0.9365 - val_loss: 6.1256 - val_accuracy: 0.3333
# Epoch 80/100
# 152/152 [==============================] - 57s 362ms/step - loss: 0.2359 - accuracy: 0.9143 - val_loss: 5.5362 - val_accuracy: 0.3366
# Epoch 81/100
# 152/152 [==============================] - 58s 369ms/step - loss: 0.2263 - accuracy: 0.9225 - val_loss: 6.3109 - val_accuracy: 0.3300
# Epoch 82/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.2198 - accuracy: 0.9151 - val_loss: 4.1577 - val_accuracy: 0.3399
# Epoch 83/100
# 152/152 [==============================] - 56s 352ms/step - loss: 0.2805 - accuracy: 0.9019 - val_loss: 5.2372 - val_accuracy: 0.3300
# Epoch 84/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.2156 - accuracy: 0.9217 - val_loss: 4.4952 - val_accuracy: 0.3366
# Epoch 85/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.2128 - accuracy: 0.9233 - val_loss: 4.4567 - val_accuracy: 0.3366
# Epoch 86/100
# 152/152 [==============================] - 58s 366ms/step - loss: 0.1935 - accuracy: 0.9233 - val_loss: 7.4262 - val_accuracy: 0.3333
# Epoch 87/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.2143 - accuracy: 0.9258 - val_loss: 4.9712 - val_accuracy: 0.3267
# Epoch 88/100
# 152/152 [==============================] - 56s 356ms/step - loss: 0.2109 - accuracy: 0.9324 - val_loss: 5.3706 - val_accuracy: 0.3333
# Epoch 89/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.2285 - accuracy: 0.9217 - val_loss: 4.1766 - val_accuracy: 0.3498
# Epoch 90/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.1573 - accuracy: 0.9365 - val_loss: 2.7010 - val_accuracy: 0.3399
# Epoch 91/100
# 152/152 [==============================] - 58s 366ms/step - loss: 0.2354 - accuracy: 0.9266 - val_loss: 5.9663 - val_accuracy: 0.3333
# Epoch 92/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.1915 - accuracy: 0.9365 - val_loss: 6.6006 - val_accuracy: 0.3333
# Epoch 93/100
# 152/152 [==============================] - 56s 353ms/step - loss: 0.1897 - accuracy: 0.9349 - val_loss: 5.2776 - val_accuracy: 0.3333
# Epoch 94/100
# 152/152 [==============================] - 56s 354ms/step - loss: 0.2352 - accuracy: 0.9217 - val_loss: 4.5951 - val_accuracy: 0.3300
# Epoch 95/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.1688 - accuracy: 0.9415 - val_loss: 5.1598 - val_accuracy: 0.3366
# Epoch 96/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.1764 - accuracy: 0.9472 - val_loss: 8.4164 - val_accuracy: 0.3300
# Epoch 97/100
# 152/152 [==============================] - 58s 367ms/step - loss: 0.1807 - accuracy: 0.9373 - val_loss: 3.4622 - val_accuracy: 0.3366
# Epoch 98/100
# 152/152 [==============================] - 56s 357ms/step - loss: 0.2026 - accuracy: 0.9225 - val_loss: 6.1888 - val_accuracy: 0.3300
# Epoch 99/100
# 152/152 [==============================] - 57s 359ms/step - loss: 0.1684 - accuracy: 0.9390 - val_loss: 7.1106 - val_accuracy: 0.3333
# Epoch 100/100
# 152/152 [==============================] - 56s 355ms/step - loss: 0.2102 - accuracy: 0.9258 - val_loss: 6.1762 - val_accuracy: 0.3234

# %%
def show_final_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('acc')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()
show_final_history(history)#

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/baseline_trained_dropout')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 5). These functions will not be directly callable after loading.

# %%
print(model)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f2c100b1e50>

# %%
import os
import numpy as np
from os import listdir
# make confution matrix
confution_matrix = np.zeros((3,3), dtype=int)


# get the path/directory
from tensorflow import keras
model = keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/baseline_trained_dropout')
predictions = model.predict(whole_ds)
# Out:
# 190/190 [==============================] - 47s 234ms/step

# %%
predictions.shape
# Out:
# (1516, 3)

# %%
# if already 0-2, then this part no need
predicted_class = np.argmax(predictions, axis=1)
print(predicted_class)
print(np.min(predicted_class))
print(np.max(predicted_class))
# Out:
# [1 1 1 ... 1 1 1]
# 0
# 2

# %%
labeled_class = np.concatenate([label for img, label in whole_ds], axis = 0)#bacause labels form dataset are 1-3 so need to -1

# %%
print(np.min(labeled_class))
print(np.max(labeled_class))
# Out:
# 0
# 2

# %%
print(labeled_class)
# Out:
# [1 0 2 ... 1 0 1]

# %%
# confusion matrix
# https://www.tensorflow.org/api_docs/python/tf/math/confusion_matrix
# confusion_matrix(labels, predictions)
# The rows of the matrix represent the labels
# tf.math.confusion_matrix(labeled_class, predicted_class)

confusion_matrix = tf.math.confusion_matrix(
    labeled_class,
    predicted_class,
    num_classes=3,
    weights=None,
    dtype=tf.dtypes.int32,
    name=None
)

# %%
print(confusion_matrix)
# Out:
# tf.Tensor(
# [[ 13 491  21]
#  [  4 478  18]
#  [ 16 460  15]], shape=(3, 3), dtype=int32)

# %%
print("correct 0 percentage is:", 100* confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[0][1]+confusion_matrix[0][2]))
print("correct 1 percentage is:", 100* confusion_matrix[1][1]/(confusion_matrix[1][0]+confusion_matrix[1][1]+confusion_matrix[1][2]))
print("correct 2 percentage is:", 100* confusion_matrix[2][2]/(confusion_matrix[2][0]+confusion_matrix[2][1]+confusion_matrix[2][2]))
# Out:
# correct 0 percentage is: tf.Tensor(2.4761904761904763, shape=(), dtype=float64)
# correct 1 percentage is: tf.Tensor(95.6, shape=(), dtype=float64)
# correct 2 percentage is: tf.Tensor(3.054989816700611, shape=(), dtype=float64)

# %%
# print("correct 0 percentage is:", 100* confusion_matrix[0][0]/(confusion_matrix[0][0]+confusion_matrix[1][0]+confusion_matrix[2][0]))
# print("correct 1 percentage is:", 100* confusion_matrix[1][1]/(confusion_matrix[0][1]+confusion_matrix[1][1]+confusion_matrix[2][1]))
# print("correct 2 percentage is:", 100* confusion_matrix[2][2]/(confusion_matrix[0][2]+confusion_matrix[1][2]+confusion_matrix[2][2]))
